# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubennino91/Datos/blob/main/ACA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Definir las librerias


import pandas as pd
import matplotlib.pyplot as plt

# %%
#Dataframer


datasept=pd.read_csv("https://raw.githubusercontent.com/Rubennino91/Datos/main/Septiembre%202023%20exportaciones%20Col%201.csv")
datasept.head()
# Out:
# <ipython-input-2-7f9e7e25fd67>:4: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   datasept=pd.read_csv("https://raw.githubusercontent.com/Rubennino91/Datos/main/Septiembre%202023%20exportaciones%20Col%201.csv")
#    FECH  ADUA  PAIS COD_PAI4  COD_SAL1 COD_SAL  DPTO2  VIA  BANDERA  REGIM  \
# 0  2309     1   249      USA         0     AXM     68    9      249      1
# 1  2309     1   580      PAN         0     AXM     68    0      580      1
# 2  2309     3    17      ALB         3     BOG     11    3       23      1
# 3  2309     3    23      DEU         3     BOG      5    3       23      1
# 4  2309     3    23      DEU         3     BOG      5    3       23      1
#
#    ...  CODUNI2  CANTI    PBK    PNK  FOBDOL     FOBPES  AGRENA   FLETES  \
# 0  ...       M3    102  90943  82676   99637  393657500     0.0     0.00
# 1  ...       M3     11  11047   9206    9517   37601143     0.0     0.00
# ...

# %%
datasept.tail()
# Out:
#        FECH  ADUA  PAIS COD_PAI4  COD_SAL1 COD_SAL  DPTO2  VIA  BANDERA  \
# 38914  2309    90   917      XCF        11     MDE      5    9      999
# 38915  2309    90   917      XCF        11     MDE      5    9      999
# 38916  2309    90   917      XCF        11     MDE      5    9      999
# 38917  2309    90   917      XCF        11     MDE      5    9      999
# 38918  2309    90   917      XCF        11     MDE     11    9      999
#
#        REGIM  ...  CODUNI2  CANTI  PBK  PNK   FOBDOL       FOBPES   AGRENA  \
# 38914      1  ...        U    100   66   60      400      1637216   240.10
# 38915      1  ...       KG     91  102   91  4814344  19207420065     0.00
# 38916      1  ...       KG     27   29   27   653303   2588090617     0.00
# 38917      4  ...       KG     15   19   15   861251   3450304721     0.00
# 38918      1  ...       KG    201  209  201     5302     20717434  4754.67
#
#       FLETES  SEGURO OTROSG
# 38914    0.0     0.0    0.0
# ...

# %%
datasept.columns
# Out:
# Index(['FECH', 'ADUA', 'PAIS', 'COD_PAI4', 'COD_SAL1', 'COD_SAL', 'DPTO2',
#        'VIA', 'BANDERA', 'REGIM', 'MODAD', 'FINALID', 'CER_ORI1', 'SISESP',
#        'POSAR', 'DPTO1', 'UNID', 'CODUNI2', 'CANTI', 'PBK', 'PNK', 'FOBDOL',
#        'FOBPES', 'AGRENA', 'FLETES', 'SEGURO', 'OTROSG'],
#       dtype='object')

# %%
datasept.describe()
# Out:
#           FECH          ADUA          PAIS      COD_SAL1         DPTO2  \
# count  38919.0  38919.000000  38919.000000  38919.000000  38919.000000
# mean    2309.0     37.289088    368.246718     13.845577     22.365657
# std        0.0     27.892353    211.722773     14.129948     23.270321
# min     2309.0      1.000000     17.000000      0.000000      0.000000
# 25%     2309.0      3.000000    239.000000      3.000000      5.000000
# 50%     2309.0     37.000000    249.000000      6.000000     11.000000
# 75%     2309.0     48.000000    580.000000     35.000000     25.000000
# max     2309.0     90.000000    954.000000     46.000000     86.000000
#
#                 VIA       BANDERA         REGIM         MODAD       FINALID  \
# count  38919.000000  38919.000000  38919.000000  38919.000000  38919.000000
# mean       4.903286    397.955523      1.015674    189.346386      1.086590
# std        3.629566    218.467860      0.240255     39.202122      0.281237
# ...

# %%
datasept.interpolate()
# Out:
#        FECH  ADUA  PAIS COD_PAI4  COD_SAL1 COD_SAL  DPTO2  VIA  BANDERA  \
# 0      2309     1   249      USA         0     AXM     68    9      249
# 1      2309     1   580      PAN         0     AXM     68    0      580
# 2      2309     3    17      ALB         3     BOG     11    3       23
# 3      2309     3    23      DEU         3     BOG      5    3       23
# 4      2309     3    23      DEU         3     BOG      5    3       23
# ...     ...   ...   ...      ...       ...     ...    ...  ...      ...
# 38914  2309    90   917      XCF        11     MDE      5    9      999
# 38915  2309    90   917      XCF        11     MDE      5    9      999
# 38916  2309    90   917      XCF        11     MDE      5    9      999
# 38917  2309    90   917      XCF        11     MDE      5    9      999
# 38918  2309    90   917      XCF        11     MDE     11    9      999
#
#        REGIM  ...  CODUNI2  CANTI    PBK    PNK   FOBDOL       FOBPES  \
# ...

# %%
datasept.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38919 entries, 0 to 38918
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FECH      38919 non-null  int64
#  1   ADUA      38919 non-null  int64
#  2   PAIS      38919 non-null  int64
#  3   COD_PAI4  38919 non-null  object
#  4   COD_SAL1  38919 non-null  int64
#  5   COD_SAL   38919 non-null  object
#  6   DPTO2     38919 non-null  int64
#  7   VIA       38919 non-null  int64
#  8   BANDERA   38919 non-null  int64
#  9   REGIM     38919 non-null  int64
#  10  MODAD     38919 non-null  int64
#  11  FINALID   38919 non-null  int64
#  12  CER_ORI1  38919 non-null  int64
#  13  SISESP    38919 non-null  int64
#  14  POSAR     38919 non-null  int64
#  15  DPTO1     38919 non-null  int64
#  16  UNID      38919 non-null  int64
#  17  CODUNI2   38919 non-null  object
#  18  CANTI     38919 non-null  int64
#  19  PBK       38919 non-null  object
# ...

# %%
datasept.kurtosis()
# Out:
# <ipython-input-8-b2e21d4d7ab7>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datasept.kurtosis()
# FECH            0.000000
# ADUA           -0.568896
# PAIS           -0.497716
# COD_SAL1       -1.060457
# DPTO2           0.773754
# VIA            -1.689059
# BANDERA        -0.593644
# REGIM         241.812505
# MODAD          16.050103
# FINALID         6.644471
# CER_ORI1        4.939479
# SISESP          0.225514
# POSAR          -1.140413
# DPTO1           0.813914
# UNID            3.517458
# CANTI        1767.433727
# FOBDOL      10352.052447
# FOBPES      10313.393730
# AGRENA       2111.597463
# FLETES       5020.049945
# SEGURO       2559.425653
# OTROSG      12331.810319
# dtype: float64
